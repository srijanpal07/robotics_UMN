# %%
import nltk
from nltk.corpus import stopwords
from nltk.lm.preprocessing import flatten, pad_both_ends, padded_everygram_pipeline
from nltk.lm import MLE
from nltk.util import bigrams
from nltk.util import everygrams

import string, sys


def data_preprocessing(name, test):
    # Declare necessary variables 
    clean_words = {}
    
    sentences = []
    ftemp = open(name[:-1], 'r', encoding='utf-8')
    temp_lines = ftemp.readlines()
    real_lines = ""
    for line in temp_lines:
        real_lines += line
    sentences = real_lines.split('.')

    # Clean the data 
    table = str.maketrans('', '', string.punctuation)
    stripped = []
    clean_sentences = []
    for sentence in sentences[:-1]:
        stripped = sentence.translate(table)
        lower = stripped.lower()
        individual_sentence = lower.split()

        # Remove non-alphabetic strings (i.e. punctuation) from the data
        clean_sentence = []
        for word in individual_sentence:
            alpha = "" 
            for index in word:
                if index.isalpha():
                    alpha += index
            if alpha != "":
                clean_sentence += [alpha]
        clean_sentences += [clean_sentence]

    ftemp.close()
    if not test:
        train, vocab = padded_everygram_pipeline(3, clean_sentences)
        return [name, (train, vocab), []]
    else:
        # Break data into train and dev set
        clean_length = len(clean_sentences)//10
        train_set = clean_sentences[clean_length+1:]

        #train model on train set
        train, vocab = padded_everygram_pipeline(3, train_set)

        #separate dev set and create everygrams based on each sentence
        dev_set = clean_sentences[:clean_length]
        every = []
        for sentence in dev_set:
            padded_trigrams = list(pad_both_ends(sentence, n=3))
            every += [list(everygrams(padded_trigrams, max_len=3))]
        return [name, (train, vocab), every]

# %%
def test_data_processing(name):
    # Declare necessary variables 

    ftemp = open(name, 'r', encoding='utf-8')
    temp_lines = ftemp.readlines()
    table = str.maketrans('', '', string.punctuation)
    clean_sentences = []
    every = []

    for line in temp_lines:
        stripped = []

        # Clean the data 
        stripped = line.translate(table)
        lower = stripped.lower()
        individual_sentence = lower.split()

        # Remove non-alphabetic strings (i.e. punctuation) from the data
        clean_sentence = []
        for word in individual_sentence:
            alpha = "" 
            for index in word:
                if index.isalpha():
                    alpha += index
            if alpha != "":
                clean_sentence += [alpha]
        clean_sentences += [clean_sentence]
    
    for sentence in clean_sentences:
        padded_trigrams = list(pad_both_ends(sentence, n=3))
        every += [list(everygrams(padded_trigrams, max_len=3))]

    ftemp.close()
    return every

# %%
def model_training(name, model, order):
    lm = MLE(order)

    train = model[0]
    vocab = model[1]
    lm.fit(train, vocab)

    return lm

# %%
def use_model(model, sequence):
    print(model.perplexity(sequence))

# %%
print("\nTraining the model...")
model_list = []
sentence_data = []

for key, value in processed_data.items():
    print(key)
    print(value[0])
    model_list += [model_training(key, value, 3)]
    sentence_data += value[2]
#     print(sentence_data)
# Out:
# Training the model...
# austen_utf8.txt
# <generator object padded_everygram_pipeline.<locals>.<genexpr> at 0x000002EA13C26740>
# dickens_utf8.txt
# <generator object padded_everygram_pipeline.<locals>.<genexpr> at 0x000002EA19CD8900>
# tolstoy_utf8.txt
# <generator object padded_everygram_pipeline.<locals>.<genexpr> at 0x000002EA150F8970>
# wilde_utf8.txt
# <generator object padded_everygram_pipeline.<locals>.<genexpr> at 0x000002EA1477BC10>

# %%
print("\nUsing the trained model...")
use_model(model_list[0], [('i','went'),('to','the')])
# Out:
# Using the trained model...
# ['family', 'may', 'be']
# 135.215395295802

# %%
model_list[0].generate(50, random_seed=8)
# Out:
# ['but',
#  'without',
#  'any',
#  'such',
#  'a',
#  'girl',
#  'with',
#  'charlotte',
#  'out',
#  'of',
#  'it',
#  'may',
#  'be',
#  'talked',
#  'about',
#  'her',
#  '</s>',
#  'course',
#  'may',
#  'suppose',
#  'mr',
#  '</s>',
#  'constant',
#  'source',
#  'of',
#  'patience',
#  'selfcontrol',
#  'but',
#  'if',
#  'that',
#  'love',
#  'of',
#  'things',
#  'of',
#  'course',
#  '</s>',
#  'what',
#  'is',
#  'capableat',
#  'least',
#  'knew',
#  'that',
#  'to',
#  'eat',
#  'any',
#  'thing',
#  'about',
#  'the',
#  'chief',
#  'of']

# %%
def data_preprocessing(name, test):
    # Declare necessary variables 
    clean_words = {}
    
    sentences = []
    ftemp = open(name[:-1], 'r', encoding='utf-8')
    temp_lines = ftemp.readlines()
    real_lines = ""
    for line in temp_lines:
        real_lines += line
    sentences = real_lines.split('.')

    # Clean the data 
    table = str.maketrans('', '', string.punctuation)
    stripped = []
    clean_sentences = []
    for sentence in sentences[:-1]:
        stripped = sentence.translate(table)
        lower = stripped.lower()
        individual_sentence = lower.split()

        # Remove non-alphabetic strings (i.e. punctuation) from the data
        clean_sentence = []
        for word in individual_sentence:
            alpha = "" 
            for index in word:
                if index.isalpha():
                    alpha += index
            if alpha != "":
                clean_sentence += [alpha]
        clean_sentences += [clean_sentence]

    ftemp.close()
    if not test:
        train, vocab = padded_everygram_pipeline(3, clean_sentences)
        return [name, (train, vocab), []]
    else:
        # Break data into train and dev set
        clean_length = len(clean_sentences)//10
        train_set = clean_sentences[clean_length+1:]

        #train model on train set
        train, vocab = padded_everygram_pipeline(3, train_set)

        #separate dev set and create everygrams based on each sentence
        dev_set = clean_sentences[:clean_length]
        every = []
        for sentence in dev_set:
            padded_trigrams = list(pad_both_ends(sentence, n=3))
            every += [list(everygrams(padded_trigrams, max_len=3))]
        return [name, (train, vocab), every]

# %%
print(data_preprocessing('austen_utf8.txt ', True))
# Out:
# ['austen_utf8.txt ', (<generator object padded_everygram_pipeline.<locals>.<genexpr> at 0x000002EA16F867B0>, <itertools.chain object at 0x000002EA180A11C0>), [[('<s>',), ('<s>', '<s>'), ('<s>', '<s>', 'family'), ('<s>',), ('<s>', 'family'), ('<s>', 'family', 'may'), ('family',), ('family', 'may'), ('family', 'may', 'be'), ('may',), ('may', 'be'), ('may', 'be', '</s>'), ('be',), ('be', '</s>'), ('be', '</s>', '</s>'), ('</s>',), ('</s>', '</s>'), ('</s>',)], [('<s>',), ('<s>', '<s>'), ('<s>', '<s>', 'we'), ('<s>',), ('<s>', 'we'), ('<s>', 'we', 'ought'), ('we',), ('we', 'ought'), ('we', 'ought', 'to'), ('ought',), ('ought', 'to'), ('ought', 'to', 'be'), ('to',), ('to', 'be'), ('to', 'be', 'acquainted'), ('be',), ('be', 'acquainted'), ('be', 'acquainted', 'with'), ('acquainted',), ('acquainted', 'with'), ('acquainted', 'with', 'enscombe'), ('with',), ('with', 'enscombe'), ('with', 'enscombe', 'and'), ('enscombe',), ('enscombe', 'and'), ('enscombe', 'and', 'with'), ('and',), ('and', 'with'), ('and', 'with', 'mrs'), ('with',), ('with', 'mrs'), ('with', 'mrs', '</s>'), ('mrs',), ('mrs', '</s>'), ('mrs', '</s>', '</s>'), ('</s>',), ('</s>', '</s>'), ('</s>',)], [('<s>',), ('<s>', '<s>'), ('<s>', '<s>', 'churchills'), ('<s>',), ('<s>', 'churchills'), ('<s>', 'churchills', 'temper'), ('churchills',), ('churchills', 'temper'), ('churchills', 'temper', 'before'), ('temper',), ('temper', 'before'), ('temper', 'before', 'we'), ('before',), ('before', 'we'), ('before', 'we', 'pretend'), ('we',), ('we', 'pretend'), ('we', 'pretend', 'to'), ('pretend',), ('pretend', 'to'), ('pretend', 'to', 'decide'), ('to',), ('to', 'decide'), ('to', 'decide', 'upon'), ('decide',), ('decide', 'upon'), ('decide', 'upon', 'what'), ('upon',), ('upon', 'what'), ('upon', 'what', 'her'), ('what',), ('what', 'her'), ('what', 'her', 'nephew'), ('her',), ('her', 'nephew'), ('her', 'nephew', 'can'), ('nephew',), ('nephew', 'can'), ('nephew', 'can', 'do'), ('can',), ('can', 'do'), ('can', 'do', '</s>'), ('do',), ('do', '</s>'), ('do', '</s>', '</s>'), ('</s>',), ('</s>', '</s>'), ('</s>',)], [('<s>',), ('<s>', '<s>'), ('<s>', '<s>', 'he'), ('<s>',), ('<s>', 'he'), ('<s>', 'he', 'may'), ('he',), ('he', 'may'), ('he', 'may', 'at'), ('may',), ('may', 'at'), ('may', 'at', 'times'), ('at',), ('at', 'times'), ('at', 'times', 'be'), ('times',), ('times', 'be'), ('times', 'be', 'able'), ('be',), ('be', 'able'), ('be', 'able', 'to'), ('able',), ('able', 'to'), ('able', 'to', 'do'), ('to',), ('to', 'do'), ('to', 'do', 'a'), ('do',), ('do', 'a'), ('do', 'a', 'great'), ('a',), ('a', 'great'), ('a', 'great', 'deal'), ('great',), ('great', 'deal'), ('great', 'deal', 'more'), ('deal',), ('deal', 'more'), ('deal', 'more', 'than'), ('more',), ('more', 'than'), ('more', 'than', 'he'), ('than',), ('than', 'he'), ('than', 'he', 'can'), ('he',), ('he', 'can'), ('he', 'can', 'at'), ('can',), ('can', 'at'), ('can', 'at', 'others'), ('at',), ('at', 'others'), ('at', 'others', '</s>'), ('others',), ('others', '</s>'), ('others', '</s>', '</s>'), ('</s>',), ('</s>', '</s>'), ('</s>',)], [('<s>',), ('<s>', '<s>'), ('<s>', '<s>', 'there'), ('<s>',), ('<s>', 'there'), ('<s>', 'there', 'is'), ('there',), ('there', 'is'), ('there', 'is', 'one'), ('is',), ('is', 'one'), ('is', 'one', 'thing'), ('one',), ('one', 'thing'), ('one', 'thing', 'emma'), ('thing',), ('thing', 'emma'), ('thing', 'emma', 'which'), ('emma',), ('emma', 'which'), ('emma', 'which', 'a'), ('which',), ('which', 'a'), ('which', 'a', 'man'), ('a',), ('a', 'man'), ('a', 'man', 'can'), ('man',), ('man', 'can'), ('man', 'can', 'always'), ('can',), ('can', 'always'), ('can', 'always', 'do'), ('always',), ('always', 'do'), ('always', 'do', 'if'), ('do',), ('do', 'if'), ('do', 'if', 'he'), ('if',), ('if', 'he'), ('if', 'he', 'chuses'), ('he',), ('he', 'chuses'), ('he', 'chuses', 'and'), ('chuses',), ('chuses', 'and'), ('chuses', 'and', 'that'), ('and',), ('and', 'that'), ('and', 'that', 'is'), ('that',), ('that', 'is'), ('that', 'is', 'his ...
